# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('D:\data set\\COVID DEATHS.csv')

# %%
df[50:60]
# Out:
#    iso_code continent     location       date  population  total_cases  \
# 50      AFG      Asia  Afghanistan  2/22/2020    41128772          NaN
# 51      AFG      Asia  Afghanistan  2/23/2020    41128772          NaN
# 52      AFG      Asia  Afghanistan  2/24/2020    41128772          5.0
# 53      AFG      Asia  Afghanistan  2/25/2020    41128772          5.0
# 54      AFG      Asia  Afghanistan  2/26/2020    41128772          5.0
# 55      AFG      Asia  Afghanistan  2/27/2020    41128772          5.0
# 56      AFG      Asia  Afghanistan  2/28/2020    41128772          5.0
# 57      AFG      Asia  Afghanistan  2/29/2020    41128772          5.0
# 58      AFG      Asia  Afghanistan   3/1/2020    41128772          5.0
# 59      AFG      Asia  Afghanistan   3/2/2020    41128772          5.0
#
#     new_cases  new_cases_smoothed  total_deaths  new_deaths  ...  \
# 50        0.0               0.000           NaN         0.0  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302749 entries, 0 to 302748
# Data columns (total 26 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   iso_code                            302749 non-null  object
#  1   continent                           288347 non-null  object
#  2   location                            302749 non-null  object
#  3   date                                302749 non-null  object
#  4   population                          302749 non-null  int64
#  5   total_cases                         266771 non-null  float64
#  6   new_cases                           294064 non-null  float64
#  7   new_cases_smoothed                  292800 non-null  float64
#  8   total_deaths                        246214 non-null  float64
#  9   new_deaths                          294139 non-null  float64
#  10  new_deaths_smoothed                 292909 non-null  float64
# ...

# %%
df.shape
# Out:
# (302749, 26)

# %%
df.isnull().sum()
# Out:
# iso_code                                   0
# continent                              14402
# location                                   0
# date                                       0
# population                                 0
# total_cases                            35978
# new_cases                               8685
# new_cases_smoothed                      9949
# total_deaths                           56535
# new_deaths                              8610
# new_deaths_smoothed                     9840
# total_cases_per_million                35978
# new_cases_per_million                   8685
# new_cases_smoothed_per_million          9949
# total_deaths_per_million               56535
# new_deaths_per_million                  8610
# new_deaths_smoothed_per_million         9840
# reproduction_rate                     117932
# icu_patients                          267883
# icu_patients_per_million              267883
# hosp_patients                         267507
# ...

# %%
df2=df.fillna(value=0)

# %%
df2[50:60]
# Out:
#    iso_code continent     location       date  population  total_cases  \
# 50      AFG      Asia  Afghanistan  2/22/2020    41128772          0.0
# 51      AFG      Asia  Afghanistan  2/23/2020    41128772          0.0
# 52      AFG      Asia  Afghanistan  2/24/2020    41128772          5.0
# 53      AFG      Asia  Afghanistan  2/25/2020    41128772          5.0
# 54      AFG      Asia  Afghanistan  2/26/2020    41128772          5.0
# 55      AFG      Asia  Afghanistan  2/27/2020    41128772          5.0
# 56      AFG      Asia  Afghanistan  2/28/2020    41128772          5.0
# 57      AFG      Asia  Afghanistan  2/29/2020    41128772          5.0
# 58      AFG      Asia  Afghanistan   3/1/2020    41128772          5.0
# 59      AFG      Asia  Afghanistan   3/2/2020    41128772          5.0
#
#     new_cases  new_cases_smoothed  total_deaths  new_deaths  ...  \
# 50        0.0               0.000           0.0         0.0  ...
# ...

# %%
df2.isnull().sum()
# Out:
# iso_code                              0
# continent                             0
# location                              0
# date                                  0
# population                            0
# total_cases                           0
# new_cases                             0
# new_cases_smoothed                    0
# total_deaths                          0
# new_deaths                            0
# new_deaths_smoothed                   0
# total_cases_per_million               0
# new_cases_per_million                 0
# new_cases_smoothed_per_million        0
# total_deaths_per_million              0
# new_deaths_per_million                0
# new_deaths_smoothed_per_million       0
# reproduction_rate                     0
# icu_patients                          0
# icu_patients_per_million              0
# hosp_patients                         0
# hosp_patients_per_million             0
# weekly_icu_admissions                 0
# ...

# %%
df.groupby('location').sum().head(20)
# Out:
# C:\Users\Aslam Computer\AppData\Local\Temp\ipykernel_8732\3418100727.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('location').sum().head(20)
#                         population   total_cases    new_cases  \
# location
# Afghanistan            49190011312  1.370889e+08     211631.0
# Africa               1706376990344  8.355807e+09   13075600.0
# Albania                 3399412328  1.960173e+08     333897.0
# Algeria                53704260688  1.917020e+08     271613.0
# American Samoa            52976820  2.903711e+06       8326.0
# Andorra                   95492228  2.614080e+07      47939.0
# Angola                 42564439216  6.357720e+07     105353.0
# Anguilla                  18988892  1.711360e+06       3904.0
# ...

# %%
data=df.groupby('location')['population','total_deaths','new_cases'].sum()
# Out:
# C:\Users\Aslam Computer\AppData\Local\Temp\ipykernel_8732\3852643924.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data=df.groupby('location')['population','total_deaths','new_cases'].sum()

# %%
data.head()
# Out:
#                    population  total_deaths   new_cases
# location
# Afghanistan       49190011312     5688108.0    211631.0
# Africa          1706376990344   183371578.0  13075600.0
# Albania            3399412328     2600799.0    333897.0
# Algeria           53704260688     5127047.0    271613.0
# American Samoa       52976820       12000.0      8326.0

# %%
data=df.groupby('location')['population','total_deaths','new_cases'].sum().sort_values(ascending=False)
# Out:
# C:\Users\Aslam Computer\AppData\Local\Temp\ipykernel_8732\896927636.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data=df.groupby('location')['population','total_deaths','new_cases'].sum().sort_values(ascending=False)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 data=df.groupby('location')['population','total_deaths','new_cases'].sum().sort_values(ascending=False)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
# ...

# %%
data = df.groupby('location')[['population', 'total_deaths', 'new_cases']].sum()
sorted_data = data.sort_values(by='total_deaths', ascending=True)

# %%
sorted_data.head(20)
# Out:
#                    population  total_deaths  new_cases
# location
# Pitcairn                56212           0.0        4.0
# England           63279450000           0.0        0.0
# North Korea       31179021536           0.0        0.0
# Taiwan            28385354448           0.0        0.0
# Tokelau               2264028           0.0        5.0
# Falkland Islands      4545996           0.0     1923.0
# Turkmenistan       7691209292           0.0        0.0
# Hong Kong          8776947436           0.0        0.0
# Scotland           6143784000           0.0        0.0
# Tuvalu               13556660           0.0     2779.0
# Northern Cyprus     264539676           0.0        0.0
# Saint Helena          6459596           0.0     2166.0
# Vatican                966368           0.0       26.0
# Niue                  2334592           0.0      747.0
# Wales              3509190000           0.0        0.0
# Northern Ireland   2157648000           0.0        0.0
# ...

# %%
sorted_data = data.sort_values(by=['total_deaths','population'], ascending=[True,True])

# %%
sorted_data.head(10)
# Out:
#                   population  total_deaths  new_cases
# location
# Pitcairn               56212           0.0        4.0
# Western Sahara        576005           0.0        0.0
# Vatican               966368           0.0       26.0
# Tokelau              2264028           0.0        5.0
# Niue                 2334592           0.0      747.0
# Falkland Islands     4545996           0.0     1923.0
# Saint Helena         6459596           0.0     2166.0
# Tuvalu              13556660           0.0     2779.0
# Northern Cyprus    264539676           0.0        0.0
# Macao              552668100           0.0        0.0

# %%
sorted_data[sorted_data.total_deaths<20]
# Out:
#                    population  total_deaths  new_cases
# location
# Pitcairn                56212           0.0        4.0
# Western Sahara         576005           0.0        0.0
# Vatican                966368           0.0       26.0
# Tokelau               2264028           0.0        5.0
# Niue                  2334592           0.0      747.0
# Falkland Islands      4545996           0.0     1923.0
# Saint Helena          6459596           0.0     2166.0
# Tuvalu               13556660           0.0     2779.0
# Northern Cyprus     264539676           0.0        0.0
# Macao               552668100           0.0        0.0
# Northern Ireland   2157648000           0.0        0.0
# Wales              3509190000           0.0        0.0
# Scotland           6143784000           0.0        0.0
# Turkmenistan       7691209292           0.0        0.0
# Hong Kong          8776947436           0.0        0.0
# Taiwan            28385354448           0.0        0.0
# ...

# %%
#remove less then 20
df=sorted_data[~(sorted_data.total_deaths<20)]

# %%
df.head()
# Out:
#                            population  total_deaths  new_cases
# location
# Nauru                        15178436         286.0     5393.0
# Cook Islands                 20370272         445.0     7042.0
# Saint Pierre and Miquelon     7038460         571.0     3426.0
# Saint Barthelemy             13148824        2747.0     5478.0
# Palau                        21628464        2982.0     5997.0
